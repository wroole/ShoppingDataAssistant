# %%
import pandas as pd

items = pd.read_csv("synthetic_data/items.csv")
receipts = pd.read_csv("synthetic_data/receipts.csv")

# %%
receipts = receipts.drop(columns=['date'])
df = pd.merge(items, receipts, on="receipt_id")

# %%
df.to_csv('final_dataset.csv', index=False)

# %%
mask = (df['category'] == 'алкоголь') & (df['date'].dt.to_period('M') == '2025-12')
total_qty = df.loc[mask, 'qty'].sum()
print(total_qty)
# Out:
# 35

# %%
df.describe()
# Out:
#           item_id                           date        price          qty  \
# count  6964.00000                           6964  6964.000000  6964.000000
# mean   3482.50000  2025-01-07 16:55:29.121194752    99.898502     1.251723
# min       1.00000            2024-01-01 00:00:00    12.000000     1.000000
# 25%    1741.75000            2024-07-14 00:00:00    25.267500     1.000000
# 50%    3482.50000            2025-01-03 00:00:00    66.050000     1.000000
# 75%    5223.25000            2025-07-16 00:00:00   157.587500     2.000000
# max    6964.00000            2025-12-29 00:00:00   374.930000     2.000000
# std    2010.47797                            NaN    90.430623     0.434034
#
#         line_total      n_items     discount        total
# count  6964.000000  6964.000000  6964.000000  6964.000000
# mean    124.331798     4.313900     2.597846   535.737346
# min      12.000000     1.000000     0.000000    12.090000
# 25%      31.937500     3.000000     0.000000   301.350000
# 50%      72.810000     5.000000     0.000000   494.030000
# 75%     177.935000     6.000000     0.000000   730.950000
# max     746.460000     6.000000   213.770000  1932.840000
# std     126.765303     1.493623    14.146403   320.616539

# %%
df.groupby('category')['line_total'].sum().sort_values(ascending=False)
# Out:
# category
# товари для тварин    322279.05
# бакалія              144176.09
# молочні              106380.24
# напої                 78828.30
# м'ясо                 49556.05
# солодощі              43036.37
# злічки                39230.59
# алкоголь              25062.14
# фрукти                19207.02
# сніданки              16024.24
# молоко                12536.48
# хліб                   9530.07
# Name: line_total, dtype: float64

# %%
df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].dt.month
spend_by_month = df.groupby(df['month'])['line_total'].sum().sort_values(ascending=False)
spend_by_month
# Out:
# month
# 8     82907.79
# 11    82234.55
# 10    76832.69
# 12    76368.99
# 9     74417.75
# 5     72372.28
# 1     71316.39
# 7     69284.64
# 2     69226.11
# 3     67112.01
# 4     62930.24
# 6     60843.20
# Name: line_total, dtype: float64

# %%
spend_for_beer = df[df["name"].str.contains('пиво', case=False)]['line_total'].sum()
print(spend_for_beer)
spend_for_milk = df[df['name'].str.contains('молоко', case=False)]['line_total'].sum()
print(spend_for_milk)
# Out:
# 25062.14
# 12536.48

# %%
import sqlite3

conn = sqlite3.connect('data.db')

df.to_sql('df', conn, index=False)
# Out:
# 6964

# %%
df.head()
# Out:
#    item_id receipt_id       date                  name   price  qty  \
# 0        1    R000001 2025-10-16    МОЛОКО 1 Л 0.5+0.5   22.09    1
# 1        2    R000002 2024-03-30        корм собак 2кг  315.77    1
# 2        3    R000002 2024-03-30   твердий сир 0.5+0.5  174.64    1
# 3        4    R000002 2024-03-30  Молоко 1 л брендовий   17.94    1
# 4        5    R000002 2024-03-30          корм котячий  236.27    1
#
#    line_total           category  n_items  discount   total  month
# 0       22.09             молоко        1       0.0   22.09     10
# 1      315.77  товари для тварин        5       0.0  831.27      3
# 2      174.64            молочні        5       0.0  831.27      3
# 3       17.94             молоко        5       0.0  831.27      3
# 4      236.27  товари для тварин        5       0.0  831.27      3

# %%
query = """
SELECT category, SUM(line_total) as total_spent
FROM df
GROUP BY category
ORDER BY total_spent DESC
LIMIT 5;
"""

top_categories = pd.read_sql_query(query, conn)
print(top_categories)
# Out:
#             category  total_spent
# 0  товари для тварин    322279.05
# 1            бакалія    144176.09
# 2            молочні    106380.24
# 3              напої     78828.30
# 4              м'ясо     49556.05

# %%
df.columns
# Out:
# Index(['item_id', 'receipt_id', 'date', 'name', 'price', 'qty', 'line_total',
#        'category', 'n_items', 'discount', 'total', 'month'],
#       dtype='object')

# %%
query = """
WITH counts AS (
    SELECT n_items, COUNT(*) as num_receipts
    FROM df
    GROUP BY n_items
), most_common AS (
    SELECT n_items
    FROM counts
    WHERE num_receipts = (SELECT MAX(num_receipts) FROM counts)
)
SELECT *
FROM df
WHERE n_items IN (SELECT n_items FROM most_common);
"""
top_5_bills = pd.read_sql_query(query, conn)
print(top_5_bills)
# Out:
#       item_id receipt_id                 date                        name  \
# 0          10    R000004  2025-11-30 00:00:00               БАТОН 0.5+0.5
# 1          11    R000004  2025-11-30 00:00:00  олія оливкова 500мл економ
# 2          12    R000004  2025-11-30 00:00:00        МОЛОКО UHT 1Л ЕКОНОМ
# 3          13    R000004  2025-11-30 00:00:00                       ТАБАК
# 4          14    R000004  2025-11-30 00:00:00                      йогурт
# ...       ...        ...                  ...                         ...
# 1975     6955    R001999  2024-10-04 00:00:00                  шинка 200г
# 1976     6956    R001999  2024-10-04 00:00:00               Молоко UHT 1л
# 1977     6957    R001999  2024-10-04 00:00:00                 DogFood 2kg
# 1978     6958    R001999  2024-10-04 00:00:00                       табак
# 1979     6959    R001999  2024-10-04 00:00:00                    ПИВО 0.5
#
#        price  qty  line_total           category  n_items  discount    total  \
# 0      13.82    2       27.64               хліб        6       0.0   437.80
# 1     198.68    1      198.68            бакалія        6       0.0   437.80
# 2      17.91    1       17.91             молоко        6       0.0   437.80
# 3      54.66    1       54.66             злічки        6       0.0   437.80
# 4      17.33    2       34.66            молочні        6       0.0   437.80
# ...      ...  ...         ...                ...      ...       ...      ...
# 1975   92.91    1       92.91              м'ясо        6       0.0  1055.53
# 1976   18.71    1       18.71             молоко        6       0.0  1055.53
# 1977  312.80    1      312.80  товари для тварин        6       0.0  1055.53
# 1978   61.17    1       61.17             злічки        6       0.0  1055.53
# 1979   40.02    1       40.02           алкоголь        6       0.0  1055.53
#
#       month
# 0        11
# 1        11
# 2        11
# 3        11
# 4        11
# ...     ...
# 1975     10
# 1976     10
# 1977     10
# 1978     10
# 1979     10
#
# [1980 rows x 12 columns]
